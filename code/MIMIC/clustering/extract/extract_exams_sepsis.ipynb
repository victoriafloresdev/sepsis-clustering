# %% [markdown]
# O notebook abaixo foi criado para a extração dos exames médicos e informaçoes importantes dos pacientes sépticos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
def aggregate_events(df):
    itemid_map = {
        'Albumine': [52022, 53138, 50862, 53085],
        'Lactate': [50813, 52442, 53154],
        'Bicarbonate': [50813, 52442, 53154],
        'Chloride': [50902, 52535],
        'Hemoglobin': [50811, 51222, 51640],
        'Sodium': [50983, 52623],
        'Glucose': [50809, 50931, 52569],
        'Troponin': [51002, 51003, 52642],
        'Platelets': [51240,51704,52159],
        'INR': [51237, 51675],
        'Creatinine': [50813, 52442, 53154],
        'Bun': [51842,52647,51006],
        'Bilirubin': [50885, 53089],
        'AST': [50878, 53088],
        'ALT': [50861, 53084],
        'C_reactive': [50889],
        'ESR': [51288],
        'Bands': [51144],
        'WBC': [51301,53134,51300],
        'Oxygen_saturation': [50817],
        'Temperature': [223762],
        'Systolic_pressure': [227242, 227243],
        'Respiratory_rate': [220210],
        'Heart_rate': [220045]
    }
    
    for key, itemids in itemid_map.items():
        new_col = df['itemid'].isin(itemids) * df["value"]
        new_col[new_col == ""] = np.NaN
        new_col[new_col == "___"] = np.NaN
        df[key] = new_col
    return df

# %% [markdown]
# A base de dados "exams" pode ser gerada a partir do notebook extract_data, as outras bases são originais da MIMIC_IV

# %%
exams = pd.read_csv("exams.csv")
# Out:
# /tmp/ipykernel_172157/2978011645.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   exams = pd.read_csv("exams.csv")

# %%
sepsis3 = pd.read_csv('/scratch/haniel.botelho/physionet.org/files/mimiciv/2.2/sepsis3.csv')

# %%
icu_stays = pd.read_csv('/scratch/haniel.botelho/physionet.org/files/mimiciv/2.2/icu/icustays.csv')

# %%
sepsis3 = pd.merge(sepsis3,icu_stays[['subject_id','hadm_id','stay_id']],on =['subject_id','stay_id'],how='left' )

# %%
sepsis3_patients = sepsis3[['subject_id','hadm_id']]
sepsis3_patients
# Out:
#        subject_id   hadm_id
# 0        18421337  22413411
# 1        12207593  22795209
# 2        16513856  24463832
# 3        10656173  25778760
# 4        17921898  28841024
# ...           ...       ...
# 32965    19046950  24352151
# 32966    15954569  25851401
# 32967    15669140  29818488
# 32968    13651601  22584645
# 32969    16180713  20178444
#
# [32970 rows x 2 columns]

# %%
exams = exams.dropna(subset=['subject_id', 'hadm_id'])
exams['subject_id'] = exams['subject_id'].astype(int)
exams['hadm_id'] = exams['hadm_id'].astype(int)

# %%
exams['key'] = exams['subject_id'].astype(int).astype(str) + '_' + exams['hadm_id'].astype(int).astype(str)
sepsis3_patients['key'] = sepsis3_patients['subject_id'].astype(str) + '_' + sepsis3_patients['hadm_id'].astype(str)

# Marcar as linhas em exams que têm a combinação de subject_id e hadm_id presente em sepsis3
exams['sepsis3'] = exams['key'].isin(sepsis3_patients['key'])
# Out:
# /tmp/ipykernel_172157/1995936599.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sepsis3_patients['key'] = sepsis3_patients['subject_id'].astype(str) + '_' + sepsis3_patients['hadm_id'].astype(str)

# %% [markdown]
# #### Extração dos sépticos

# %%
diagnostics = pd.read_csv("diagnostics.csv")

# %%
diagnostics = diagnostics[['subject_id','hadm_id','sepsis']].drop_duplicates()
exams = pd.merge(diagnostics[['subject_id','hadm_id','sepsis']],exams,on = ['subject_id','hadm_id'],how = 'left')

# %%
exams['Sepsis'] = exams.apply(lambda row: 'diagnostico' if row['sepsis'] == True 
                                  else 'sepsis3' if row['sepsis3'] == True 
                                  else False, axis=1)

# %%
exams = exams.drop(['sepsis','key','sepsis3'],axis = 1)
exams = exams[exams["Sepsis"]!=False]
exams
# Out:
#           subject_id   hadm_id            charttime   itemid value  \
# 405         10000826  21086876  2146-12-18 21:20:00  51237.0   1.9
# 406         10000826  21086876  2146-12-19 05:15:00  51222.0  10.7
# 407         10000826  21086876  2146-12-19 05:15:00  51301.0  20.0
# 408         10000826  21086876  2146-12-19 05:15:00  50861.0    33
# 409         10000826  21086876  2146-12-19 05:15:00  50862.0   3.1
# ...              ...       ...                  ...      ...   ...
# 36341507    19999840  21033226  2164-09-17 13:34:00  50813.0   4.0
# 36341508    19999840  21033226  2164-09-17 13:34:00  50817.0    25
# 36341509    19999840  21033226  2164-09-17 13:39:00  50809.0   369
# 36341510    19999840  21033226  2164-09-17 13:39:00  50813.0   ___
# 36341511    19999840  21033226  2164-09-17 13:39:00  50817.0    25
#
#                Sepsis
# 405       diagnostico
# 406       diagnostico
# 407       diagnostico
# 408       diagnostico
# 409       diagnostico
# ...               ...
# 36341507      sepsis3
# 36341508      sepsis3
# 36341509      sepsis3
# 36341510      sepsis3
# 36341511      sepsis3
#
# [20692728 rows x 6 columns]

# %% [markdown]
# #### Calculo dos offsets

# %%
admissions = pd.read_csv("/scratch/haniel.botelho/physionet.org/files/mimiciv/2.2/hosp/admissions.csv")

# %%
admissions = admissions[['subject_id','hadm_id','admittime','dischtime','discharge_location']]
admissions
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 431226    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 431227    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 431228    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 431229    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 431230    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#        discharge_location
# 0                    HOME
# 1                    HOME
# 2                 HOSPICE
# 3                    HOME
# 4                     NaN
# ...                   ...
# 431226   HOME HEALTH CARE
# 431227   HOME HEALTH CARE
# 431228               DIED
# 431229               HOME
# 431230              REHAB
#
# [431231 rows x 5 columns]

# %%
exams = pd.merge(exams,admissions,on = ['subject_id','hadm_id'],how = 'left')

# %%
# Convertendo colunas para datetime
exams['charttime'] = pd.to_datetime(exams['charttime'])
exams['admittime'] = pd.to_datetime(exams['admittime'])
exams['dischtime'] = pd.to_datetime(exams['dischtime'])
# Calculando os offsets
exams['offsettime'] = exams['charttime'] - exams['admittime']
exams['offsettime_disch'] = exams['dischtime'] - exams['admittime']

# %% [markdown]
# #### Salvando a base

# %%
exams.to_csv("exams_all_sepsis.csv",index=False)

# %%
exams
# Out:
#           subject_id   hadm_id           charttime   itemid value  \
# 0           10000826  21086876 2146-12-18 21:20:00  51237.0   1.9
# 1           10000826  21086876 2146-12-19 05:15:00  51222.0  10.7
# 2           10000826  21086876 2146-12-19 05:15:00  51301.0  20.0
# 3           10000826  21086876 2146-12-19 05:15:00  50861.0    33
# 4           10000826  21086876 2146-12-19 05:15:00  50862.0   3.1
# ...              ...       ...                 ...      ...   ...
# 20692723    19999840  21033226 2164-09-17 13:34:00  50813.0   4.0
# 20692724    19999840  21033226 2164-09-17 13:34:00  50817.0    25
# 20692725    19999840  21033226 2164-09-17 13:39:00  50809.0   369
# 20692726    19999840  21033226 2164-09-17 13:39:00  50813.0   ___
# 20692727    19999840  21033226 2164-09-17 13:39:00  50817.0    25
#
#                Sepsis           admittime           dischtime  \
# 0         diagnostico 2146-12-18 17:39:00 2146-12-24 19:55:00
# 1         diagnostico 2146-12-18 17:39:00 2146-12-24 19:55:00
# 2         diagnostico 2146-12-18 17:39:00 2146-12-24 19:55:00
# 3         diagnostico 2146-12-18 17:39:00 2146-12-24 19:55:00
# 4         diagnostico 2146-12-18 17:39:00 2146-12-24 19:55:00
# ...               ...                 ...                 ...
# 20692723      sepsis3 2164-09-10 13:47:00 2164-09-17 13:42:00
# 20692724      sepsis3 2164-09-10 13:47:00 2164-09-17 13:42:00
# 20692725      sepsis3 2164-09-10 13:47:00 2164-09-17 13:42:00
# 20692726      sepsis3 2164-09-10 13:47:00 2164-09-17 13:42:00
# 20692727      sepsis3 2164-09-10 13:47:00 2164-09-17 13:42:00
#
#          discharge_location      offsettime offsettime_disch
# 0                      HOME 0 days 03:41:00  6 days 02:16:00
# 1                      HOME 0 days 11:36:00  6 days 02:16:00
# 2                      HOME 0 days 11:36:00  6 days 02:16:00
# 3                      HOME 0 days 11:36:00  6 days 02:16:00
# 4                      HOME 0 days 11:36:00  6 days 02:16:00
# ...                     ...             ...              ...
# 20692723               DIED 6 days 23:47:00  6 days 23:55:00
# 20692724               DIED 6 days 23:47:00  6 days 23:55:00
# 20692725               DIED 6 days 23:52:00  6 days 23:55:00
# 20692726               DIED 6 days 23:52:00  6 days 23:55:00
# 20692727               DIED 6 days 23:52:00  6 days 23:55:00
#
# [20692728 rows x 11 columns]
